# %% [markdown]
# # Train Interpolator (Colab)

# %%
# !pip install -r /content/requirements.txt

# %%
# !PYTHONPATH=src python -m myvideo.interpolate.train --data-dir data/processed/interp_triplets --epochs 6 --batch-size 1 --save-path models/checkpoints/interpolator_tiny.pt
