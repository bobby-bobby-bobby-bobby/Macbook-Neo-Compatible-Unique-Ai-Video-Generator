# %% [markdown]
# # Train Upscaler (Colab)

# %%
# !pip install -r /content/requirements.txt

# %%
# !PYTHONPATH=src python -m myvideo.upscale.train --image-dir data/processed/sr_train --scale 2 --epochs 6 --batch-size 1 --save-path models/checkpoints/upscaler_tiny.pt
