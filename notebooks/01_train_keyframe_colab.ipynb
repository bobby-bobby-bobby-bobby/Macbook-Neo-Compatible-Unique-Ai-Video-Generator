# %% [markdown]
# # Train Keyframe Model (Colab)

# %%
# !pip install -r /content/requirements.txt

# %%
# !PYTHONPATH=src python -m myvideo.keyframe.train --image-dir data/processed/keyframes_train --prompt 'cinematic scene' --epochs 5 --batch-size 1 --save-path models/checkpoints/keyframe_tiny.pt
