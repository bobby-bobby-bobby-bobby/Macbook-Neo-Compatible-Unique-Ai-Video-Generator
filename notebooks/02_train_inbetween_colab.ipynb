# %% [markdown]
# # Train Inbetweener (Colab)

# %%
# !pip install -r /content/requirements.txt

# %%
# !PYTHONPATH=src python -m myvideo.inbetween.train --data-dir data/processed/inbetween_triplets --epochs 6 --batch-size 1 --save-path models/checkpoints/inbetween_tiny.pt
